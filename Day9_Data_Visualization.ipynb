# %% [markdown]
# # Day 7: Data Visualization with Matplotlib & Seaborn

# %% [markdown]
# ## 🔷 Matplotlib Examples

# %%
import matplotlib.pyplot as plt
import numpy as np

# Line Plot
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True)
plt.show()

# %%
# Bar Chart
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]
plt.bar(categories, values, color='teal')
plt.title('Bar Chart')
plt.show()

# %%
# Scatter Plot
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y, color='purple')
plt.title('Scatter Plot')
plt.show()

# %%
# Pie Chart
labels = ['Python', 'Java', 'C++', 'Ruby']
sizes = [40, 25, 20, 15]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Pie Chart')
plt.axis('equal')
plt.show()

# %%
# Subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].plot([1,2,3], [4,5,6])
axs[0].set_title('Subplot 1')
axs[1].bar([1,2,3], [6,5,4])
axs[1].set_title('Subplot 2')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔷 Seaborn Examples

# %%
import seaborn as sns
import pandas as pd
df = sns.load_dataset('tips')

# %%
# Distribution Plot
sns.histplot(df['total_bill'], kde=True)
plt.title('Distribution of Total Bill')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Distribution Plot
#       2 sns.histplot(df['total_bill'], kde=True)
# ----> 3 plt.title('Distribution of Total Bill')
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# Box Plot
sns.boxplot(x='day', y='total_bill', data=df)
plt.title('Box Plot by Day')
plt.show()

# %%
# Count Plot
sns.countplot(x='day', data=df)
plt.title('Count of Days')
plt.show()

# %%
# Heatmap
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 corr = df.corr(numeric_only=True)
#       3 sns.heatmap(corr, annot=True, cmap='coolwarm')
# ----> 4 plt.title('Correlation Heatmap')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# Violin Plot
sns.violinplot(x='day', y='total_bill', data=df)
plt.title('Violin Plot by Day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Violin Plot
#       2 sns.violinplot(x='day', y='total_bill', data=df)
# ----> 3 plt.title('Violin Plot by Day')
#       4 plt.show()
#
# NameError: name 'plt' is not defined
